# %% [markdown]
# # Deep Learning (EEGNet): ds002778 — Resting State EEG
#
# Load preprocessed epochs → Convert to PyTorch tensors → Train EEGNet (braindecode) → LOSO cross-validation → Compare accuracy vs classical ML (notebook 06) → Confusion matrix
#
# > **Status:** Not yet implemented.
